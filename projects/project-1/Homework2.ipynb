# %%
# You have been recently hired to work for the
# analytics team of an investment company
# ▪ Your team is responsible for building models that
# predict asset prices
# ▪ You decided to try a naïve stochastic model

# %%
# Model: 𝑝𝑟𝑖𝑐𝑒𝑡 = 𝑝𝑟𝑖𝑐𝑒𝑡−1 + 𝜖 where 𝜖~𝑁(0, 𝜎)
# ▪ The standard deviation 𝜎 represents the uncertainty in the price movement. The
# subscript t represents an end-of-day stock price

# %%
# Task: code and run the above equation over X days, where X is equal to five
# times the total number of letters in your last name (9)
# ▪ Start by importing the module random in the first line of your code
# ▪ More on this in future classes
# ▪ import random
# ▪ In the second line, assume the initial stock price is equal to 25
# ▪ price = 25
# ▪ Use the function random.gauss(mu = 0, sigma=1) to simulate ε

# %%
# import the module random
import random

# assign the initial stock price to the asumed value of 25
price = 25

# simulate episilon using random.gauss(mu = 0, sigma=1)
epsilon = random.gauss(mu = 0, sigma=1)

# assign the value for days (five times the total number of letters in my last name (9))
days = 5 * 9

# simulate the stock price over 45 days
for x in range(days):
    price = price + epsilon
    print("Day " + str(x + 1) + ": price = " + str(price))
# Out:
# Day 1: price = 25.934621199172764
# Day 2: price = 26.869242398345527
# Day 3: price = 27.80386359751829
# Day 4: price = 28.738484796691054
# Day 5: price = 29.673105995863818
# Day 6: price = 30.60772719503658
# Day 7: price = 31.542348394209345
# Day 8: price = 32.47696959338211
# Day 9: price = 33.411590792554875
# Day 10: price = 34.34621199172764
# Day 11: price = 35.28083319090041
# Day 12: price = 36.21545439007318
# Day 13: price = 37.150075589245944
# Day 14: price = 38.08469678841871
# Day 15: price = 39.01931798759148
# Day 16: price = 39.953939186764245
# Day 17: price = 40.88856038593701
# Day 18: price = 41.82318158510978
# Day 19: price = 42.757802784282546
# Day 20: price = 43.69242398345531
# Day 21: price = 44.62704518262808
# Day 22: price = 45.56166638180085
# Day 23: price = 46.496287580973615
# Day 24: price = 47.43090878014638
# Day 25: price = 48.36552997931915
# Day 26: price = 49.300151178491916
# Day 27: price = 50.23477237766468
# ...
